# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Daten_Bewertet_Szenario2.csv", delimiter=';')
df
# Out:
#            Name  Alter Politische Orientierung Bildungsabschluss  Soziales  \
# 0       Liliane     50                   Mitte        Ausbildung         0
# 1     Catherine     62                   Links        Ausbildung         2
# 2          Otto     63                   Mitte        Ausbildung         0
# 3     Apollonia     26                   Mitte        Ausbildung         0
# 4       Ioannis     41                   Mitte        Ausbildung         0
# ...         ...    ...                     ...               ...       ...
# 9995   Gertraud     23                   Mitte              ohne         2
# 9996    Dittmar     69                   Links            Diplom         1
# 9997       Rigo     44                   Links        Ausbildung         0
# 9998      Jerzy     69                   Links            Diplom         0
# 9999    Andreas     52                   Mitte        Ausbildung         1
#
#         Wohnlage  CO2-Fußabdruck  Bewertung
# ...

# %%
freq = df.groupby(['Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Bewertung
# 600     66
# 610      3
# 620      8
# 630     11
# 640     14
#         ..
# 1320     8
# 1330     4
# 1350     1
# 1360     1
# 1380     1
# Length: 77, dtype: int64
# <AxesSubplot:ylabel='Bewertung'>
