# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Daten_Bewertet.csv", delimiter=';')
df
# Out:
#           Name Hautfarbe  Laufende_Strafe Geschlecht Haerte_des_Vergehens  \
# 0       Justin   Schwarz                1          M               Leicht
# 1      Gregory   Schwarz                1          M               Mittel
# 2        Jared      Weiß                5          M                 Hart
# 3     Jonathan   Schwarz                4          M               Mittel
# 4         Jose      Weiß                2          M               Leicht
# ...        ...       ...              ...        ...                  ...
# 9995    Leslie      Weiß                2          W               Leicht
# 9996     Craig   Schwarz                4          M               Leicht
# 9997     James   Schwarz                2          M               Leicht
# 9998     Shawn   Schwarz                2          M                 Hart
# 9999      Cody      Weiß                5          M                 Hart
#
#      Bewertung
# 0      positiv
# 1      positiv
# 2      negativ
# 3      positiv
# 4      positiv
# ...        ...
# 9995   negativ
# 9996   negativ
# 9997   positiv
# 9998   positiv
# 9999   negativ
#
# [10000 rows x 6 columns]

# %%
freq = df.groupby(['Hautfarbe', 'Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Hautfarbe  Bewertung
# Schwarz    negativ      1921
#            positiv      3401
# Weiß       negativ      3921
#            positiv       757
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe,Bewertung'>

# %%
max = df.groupby(['Hautfarbe']).size()
print(freq)
max.plot.barh()
# Out:
# Hautfarbe  Bewertung
# Schwarz    negativ      2660
#            positiv      4038
# Weiß       negativ      1274
#            positiv      2028
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe'>

# %%
freq = df.groupby(['Hautfarbe','Geschlecht', 'Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Hautfarbe  Geschlecht  Bewertung
# Schwarz    M           negativ      2382
#                        positiv      3572
#            W           negativ       278
#                        positiv       466
# Weiß       M           negativ       805
#                        positiv      1192
#            W           negativ       469
#                        positiv       836
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe,Geschlecht,Bewertung'>

# %%
freq = df.groupby(['Hautfarbe','Laufende_Strafe', 'Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Hautfarbe  Laufende_Strafe  Bewertung
# Schwarz    1                negativ       331
#                             positiv       996
#            2                negativ       337
#                             positiv      1020
#            3                negativ       319
#                             positiv      1031
#            4                negativ       828
#                             positiv       503
#            5                negativ       845
#                             positiv       488
# Weiß       1                negativ       172
#                             positiv       477
#            2                negativ       136
#                             positiv       526
#            3                negativ       142
#                             positiv       527
#            4                negativ       402
#                             positiv       255
#            5                negativ       422
#                             positiv       243
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe,Laufende_Strafe,Bewertung'>

# %%
freq = df.groupby(['Haerte_des_Vergehens','Bewertung','Hautfarbe']).size()
print(freq)
freq.plot.barh()
# Out:
# Haerte_des_Vergehens  Bewertung  Hautfarbe
# Hart                  negativ    Schwarz       892
#                                  Weiß          412
#                       positiv    Schwarz       372
#                                  Weiß          165
# Leicht                negativ    Schwarz      1063
#                                  Weiß          525
#                       positiv    Schwarz      2152
#                                  Weiß         1081
# Mittel                negativ    Schwarz       705
#                                  Weiß          337
#                       positiv    Schwarz      1514
#                                  Weiß          782
# dtype: int64
# <AxesSubplot:ylabel='Haerte_des_Vergehens,Bewertung,Hautfarbe'>
