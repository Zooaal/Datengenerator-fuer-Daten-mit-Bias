# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("Daten_Bewertet.csv", delimiter=';')
df
# Out:
#          Name Hautfarbe  Laufende_Strafe Geschlecht Haerte_des_Vergehens  \
# 0    Veronica     White                5          W               Leicht
# 1         Amy     White                3          W               Mittel
# 2       Molly     White                2          W                 Hart
# 3        John     Black                5          M               Leicht
# 4      Teresa     White                5          W               Mittel
# ..        ...       ...              ...        ...                  ...
# 995   Douglas     Black                3          M               Leicht
# 996  Nicholas     Black                3          M               Leicht
# 997       Ian     White                2          M               Leicht
# 998    Joshua     White                5          M               Leicht
# 999    Steven     White                1          M                 Hart
#
#     Bewertung
# 0     positiv
# 1     positiv
# 2     positiv
# 3     negativ
# 4     negativ
# ..        ...
# 995   positiv
# 996   positiv
# 997   positiv
# 998   negativ
# 999   positiv
#
# [1000 rows x 6 columns]

# %%
freq = df.groupby(['Hautfarbe', 'Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Hautfarbe  Bewertung
# Black      negativ      286
#            positiv      368
# White      negativ       98
#            positiv      248
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe,Bewertung'>

# %%
max = df.groupby(['Hautfarbe']).size()
print(freq)
max.plot.barh()
# Out:
# Hautfarbe  Bewertung
# Black      negativ      286
#            positiv      368
# White      negativ       98
#            positiv      248
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe'>

# %%
freq = df.groupby(['Hautfarbe','Geschlecht', 'Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Hautfarbe  Geschlecht  Bewertung
# Black      M           negativ      258
#                        positiv      334
#            W           negativ       28
#                        positiv       34
# White      M           negativ       74
#                        positiv      154
#            W           negativ       24
#                        positiv       94
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe,Geschlecht,Bewertung'>

# %%
freq = df.groupby(['Hautfarbe','Laufende_Strafe', 'Bewertung']).size()
print(freq)
freq.plot.barh()
# Out:
# Hautfarbe  Laufende_Strafe  Bewertung
# Black      1                negativ       33
#                             positiv       93
#            2                negativ       36
#                             positiv      106
#            3                negativ       41
#                             positiv       84
#            4                negativ       90
#                             positiv       36
#            5                negativ       86
#                             positiv       49
# White      1                negativ        7
#                             positiv       57
#            2                negativ        7
#                             positiv       75
#            3                negativ       13
#                             positiv       59
#            4                negativ       31
#                             positiv       25
#            5                negativ       40
#                             positiv       32
# dtype: int64
# <AxesSubplot:ylabel='Hautfarbe,Laufende_Strafe,Bewertung'>

# %%
freq = df.groupby(['Haerte_des_Vergehens','Bewertung','Hautfarbe']).size()
print(freq)
freq.plot.barh()
# Out:
# Haerte_des_Vergehens  Bewertung  Hautfarbe
# Hart                  negativ    Black         94
#                                  White         39
#                       positiv    Black         34
#                                  White         22
# Leicht                negativ    Black        103
#                                  White         36
#                       positiv    Black        192
#                                  White        139
# Mittel                negativ    Black         89
#                                  White         23
#                       positiv    Black        142
#                                  White         87
# dtype: int64
# <AxesSubplot:ylabel='Haerte_des_Vergehens,Bewertung,Hautfarbe'>
